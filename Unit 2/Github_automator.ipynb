# %%
from github import Github

# %%
g = Github("JamesC131","Malware2658!")

# %%
for repo in repos:
    print(repo)
# Out:
# Repository(full_name="langchain-ai/langchain")
# Repository(full_name="pallets/flask")
# Repository(full_name="apachecn/ailearning")
# Repository(full_name="0xAX/linux-insides")
# Repository(full_name="Vision-CAIR/MiniGPT-4")
# Repository(full_name="s0md3v/roop")
# Repository(full_name="Textualize/textual")
# Repository(full_name="magic-wormhole/magic-wormhole")
# Repository(full_name="quantopian/zipline")
# Repository(full_name="pytorch/vision")
# Repository(full_name="unifyai/ivy")
# Repository(full_name="fauxpilot/fauxpilot")
# Repository(full_name="w-okada/voice-changer")
# Repository(full_name="google/yapf")
# Repository(full_name="albumentations-team/albumentations")
# Repository(full_name="microsoft/Swin-Transformer")
# Repository(full_name="jaakkopasanen/AutoEq")
# Repository(full_name="databrickslabs/dolly")
# Repository(full_name="jopohl/urh")
# Repository(full_name="twitter/the-algorithm-ml")
# Repository(full_name="eosphoros-ai/DB-GPT")
# ...

# %%
for repo in g.get_user().get_repos():
    print(repo)

# %%
repo = g.get_repo("")
repo.stargazers_count

# %%
traffic = repo.get_views_traffic()
print(traffic)

# %%
repos = g.search_repositories(query="language:python")

# %%
content = repo.get_contents("")

# %%
for content_fil in content:
    print(content_fil)

# %%
user = g.get_user()

# %%
repo = user.create_repo('test')

# %%
repo.create_file("test.txt", "commit", "this is a test")

# %%
cont = get_contents("test.txt")
repo.delete_file(cont.path,"remove test", cont.sha, branch='#enter branch')
